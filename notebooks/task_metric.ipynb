# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# sphinx_gallery_thumbnail_number = 2


max_tasks = 7

label_y = ["Trained  "+str( i) for i in range(max_tasks)]
label_x = ["Task "+str(i) for i in range(max_tasks)]

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

data_matrix = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow(harvest)

# We want to show all ticks...
ax.set_xticks(np.arange(len(label_x)))
ax.set_yticks(np.arange(len(label_y)))
# ... and label them with the respective list entries
ax.set_xticklabels(label_x)
ax.set_yticklabels(label_y)

# Rotate the tick labels and set their alignment.

#ax.invert_xaxis()
ax.xaxis.tick_top()
plt.setp(ax.get_xticklabels(), rotation=45, ha="left",
          rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(label_x)):
    for j in range(len(label_y)):
        text = ax.text(j, i, data_matrix[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Training Result")
fig.tight_layout()
display( plt )
# Out:
# <module 'matplotlib.pyplot' from '/home/jonfrey/miniconda3/envs/track3/lib/python3.7/site-packages/matplotlib/pyplot.py'>
